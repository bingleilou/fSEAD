# %%
import pynq
import collections

from pynq import Overlay, UnsupportedConfiguration
from pynq import Bitstream
from pprint import pprint
import numpy as np
from tqdm import tqdm
import time
import re

time_pr1_f2e = []
time_pr1_e2f = []
time_pr2_f2e = []
time_pr2_e2f = []
time_pr3_f2e = []
time_pr3_e2f = []
time_pr4_f2e = []
time_pr4_e2f = []
time_pr5_f2e = []
time_pr5_e2f = []
time_pr6_f2e = []
time_pr6_e2f = []
time_pr7_f2e = []
time_pr7_e2f = []

time_combo1_f2e = []
time_combo1_e2f = []
time_combo2_f2e = []
time_combo2_e2f = []
time_combo3_f2e = []
time_combo3_e2f = []

ol = Overlay('./system.bit')
ol.download()
ol.is_loaded()
#pprint(ol.ip_dict)
########################################### PR1 ###########################################
decouper_1 = ol.dfx_decoupler_1
decouper_1.write(0x0,0)
decouper_1.write(0x0,1)
ol.pr_download('pr1','pr1_loda_cardio_c1.bit','s_axi_AXILiteS', 'pr1_loda_cardio_c1',None)
decouper_1.write(0x0,0)

decouper_1 = ol.dfx_decoupler_1
decouper_1.write(0x0,0)
decouper_1.write(0x0,1)
start_ = time.time()
ol.pr_download('pr1','pr1_empty_ad.bit','pr1_loda_cardio_c1', 'pr1_empty_ad',None)
end_ = time.time()
decouper_1.write(0x0,0)
timecost = end_ - start_

decouper_1 = ol.dfx_decoupler_1
decouper_1.write(0x0,0)
decouper_1.write(0x0,1)
start_ = time.time()
ol.pr_download('pr1','pr1_loda_cardio_c1.bit','pr1_empty_ad', 'pr1_loda_cardio_c1',None)
end_ = time.time()
decouper_1.write(0x0,0)
timecost = end_ - start_
###########################################################################################

########################################### PR2 ###########################################
decouper_2 = ol.dfx_decoupler_2
decouper_2.write(0x0,0)
decouper_2.write(0x0,1)
ol.pr_download('pr2','pr2_loda_cardio_c2.bit','s_axi_AXILiteS', 'pr2_loda_cardio_c2',None)
decouper_2.write(0x0,0)

decouper_2 = ol.dfx_decoupler_2
decouper_2.write(0x0,0)
decouper_2.write(0x0,1)
start_ = time.time()
ol.pr_download('pr2','pr2_empty_ad.bit','pr2_loda_cardio_c2', 'pr2_empty_ad',None)
end_ = time.time()
decouper_2.write(0x0,0)
timecost = end_ - start_

decouper_2 = ol.dfx_decoupler_2
decouper_2.write(0x0,0)
decouper_2.write(0x0,1)
start_ = time.time()
ol.pr_download('pr2','pr2_loda_cardio_c2.bit','pr2_empty_ad', 'pr2_loda_cardio_c2',None)
end_ = time.time()
decouper_2.write(0x0,0)
timecost = end_ - start_
###########################################################################################

########################################### PR3###########################################
decouper_3 = ol.dfx_decoupler_3
decouper_3.write(0x0,0)
decouper_3.write(0x0,1)
ol.pr_download('pr3','pr3_loda_cardio_c3.bit','s_axi_AXILiteS', 'pr3_loda_cardio_c3',None)
decouper_3.write(0x0,0)

decouper_3 = ol.dfx_decoupler_3
decouper_3.write(0x0,0)
decouper_3.write(0x0,1)
start_ = time.time()
ol.pr_download('pr3','pr3_empty_ad.bit','pr3_loda_cardio_c3', 'pr3_empty_ad',None)
end_ = time.time()
decouper_3.write(0x0,0)
timecost = end_ - start_

decouper_3 = ol.dfx_decoupler_3
decouper_3.write(0x0,0)
decouper_3.write(0x0,1)
start_ = time.time()
ol.pr_download('pr3','pr3_loda_cardio_c3.bit','pr3_empty_ad', 'pr3_loda_cardio_c3',None)
end_ = time.time()
decouper_3.write(0x0,0)
timecost = end_ - start_
###########################################################################################

########################################### PR4 ###########################################
decouper_4 = ol.dfx_decoupler_4
decouper_4.write(0x0,0)
decouper_4.write(0x0,1)
ol.pr_download('pr4','pr4_loda_cardio_c4.bit','s_axi_AXILiteS', 'pr4_loda_cardio_c4',None)
decouper_4.write(0x0,0)

decouper_4 = ol.dfx_decoupler_4
decouper_4.write(0x0,0)
decouper_4.write(0x0,1)
start_ = time.time()
ol.pr_download('pr4','pr4_empty_ad.bit','pr4_loda_cardio_c4', 'pr4_empty_ad',None)
end_ = time.time()
decouper_4.write(0x0,0)
timecost = end_ - start_

decouper_4 = ol.dfx_decoupler_4
decouper_4.write(0x0,0)
decouper_4.write(0x0,1)
start_ = time.time()
ol.pr_download('pr4','pr4_loda_cardio_c4.bit','pr4_empty_ad', 'pr4_loda_cardio_c4',None)
end_ = time.time()
decouper_4.write(0x0,0)
timecost = end_ - start_
###########################################################################################

########################################### PR5 ###########################################
decouper_5 = ol.dfx_decoupler_5
decouper_5.write(0x0,0)
decouper_5.write(0x0,1)
ol.pr_download('pr5','pr5_loda_cardio_c5.bit','s_axi_AXILiteS', 'pr5_loda_cardio_c5',None)
decouper_5.write(0x0,0)

decouper_5 = ol.dfx_decoupler_5
decouper_5.write(0x0,0)
decouper_5.write(0x0,1)
start_ = time.time()
ol.pr_download('pr5','pr5_empty_ad.bit','pr5_loda_cardio_c5', 'pr5_empty_ad',None)
end_ = time.time()
decouper_5.write(0x0,0)
timecost = end_ - start_

decouper_5 = ol.dfx_decoupler_5
decouper_5.write(0x0,0)
decouper_5.write(0x0,1)
start_ = time.time()
ol.pr_download('pr5','pr5_loda_cardio_c5.bit','pr5_empty_ad', 'pr5_loda_cardio_c5',None)
end_ = time.time()
decouper_5.write(0x0,0)
timecost = end_ - start_

###########################################################################################

########################################### PR6 ###########################################
decouper_6 = ol.dfx_decoupler_6
decouper_6.write(0x0,0)
decouper_6.write(0x0,1)
ol.pr_download('pr6','pr6_loda_cardio_c6.bit','s_axi_AXILiteS', 'pr6_loda_cardio_c6',None)
decouper_6.write(0x0,0)

decouper_6 = ol.dfx_decoupler_6
decouper_6.write(0x0,0)
decouper_6.write(0x0,1)
start_ = time.time()
ol.pr_download('pr6','pr6_empty_ad.bit','pr6_loda_cardio_c6', 'pr6_empty_ad',None)
end_ = time.time()
decouper_6.write(0x0,0)
timecost = end_ - start_
#print('pr6: cardio_2_empty timecost(ms) = ',timecost*1000)

decouper_6 = ol.dfx_decoupler_6
decouper_6.write(0x0,0)
decouper_6.write(0x0,1)
start_ = time.time()
ol.pr_download('pr6','pr6_loda_cardio_c6.bit','pr6_empty_ad', 'pr6_loda_cardio_c6',None)
end_ = time.time()
decouper_6.write(0x0,0)
timecost = end_ - start_
#print('pr6: empty_2_cardio timecost(ms) = ',timecost*1000)
###########################################################################################

########################################### PR7 ###########################################
decouper_7 = ol.dfx_decoupler_7
decouper_7.write(0x0,0)
decouper_7.write(0x0,1)
ol.pr_download('pr7','pr7_loda_cardio_c7.bit','s_axi_AXILiteS', 'pr7_loda_cardio_c7',None)
decouper_7.write(0x0,0)

decouper_7 = ol.dfx_decoupler_7
decouper_7.write(0x0,0)
decouper_7.write(0x0,1)
start_ = time.time()
ol.pr_download('pr7','pr7_empty_ad.bit','pr7_loda_cardio_c7', 'pr7_empty_ad',None)
end_ = time.time()
decouper_7.write(0x0,0)
timecost = end_ - start_
#print('pr7: cardio_2_empty timecost(ms) = ',timecost*1000)

decouper_7 = ol.dfx_decoupler_7
decouper_7.write(0x0,0)
decouper_7.write(0x0,1)
start_ = time.time()
ol.pr_download('pr7','pr7_loda_cardio_c7.bit','pr7_empty_ad', 'pr7_loda_cardio_c7',None)
end_ = time.time()
decouper_7.write(0x0,0)
timecost = end_ - start_
#print('pr7: empty_2_cardio timecost(ms) = ',timecost*1000)

###########################################################################################

########################################### PR-COMBO1 ###########################################
decouper_c1 = ol.dfx_decoupler_combo1
decouper_c1.write(0x0,0)
decouper_c1.write(0x0,1)
ol.pr_download('pr_combo_1','pr_combo_1_combo_score_i4.bit','s_axi_AXILiteS', 'pr_combo_1_combo_score_i4',None)
decouper_c1.write(0x0,0)

decouper_c1 = ol.dfx_decoupler_combo1
decouper_c1.write(0x0,0)
decouper_c1.write(0x0,1)
start_ = time.time()
ol.pr_download('pr_combo_1','pr_combo_1_empty_combo.bit','pr_combo_1_combo_score_i4', 'pr_combo_1_empty_combo',None)
end_ = time.time()
decouper_c1.write(0x0,0)
timecost = end_ - start_
#print('pr_combo_1: cardio_2_empty timecost(ms) = ',timecost*1000)

decouper_c1 = ol.dfx_decoupler_combo1
decouper_c1.write(0x0,0)
decouper_c1.write(0x0,1)
start_ = time.time()
ol.pr_download('pr_combo_1','pr_combo_1_combo_score_i4.bit','pr_combo_1_empty_combo', 'pr_combo_1_combo_score_i4',None)
end_ = time.time()
decouper_c1.write(0x0,0)
timecost = end_ - start_
#print('pr_combo_1: empty_2_cardio timecost(ms) = ',timecost*1000)
###########################################################################################

########################################### PR-COMBO2 ###########################################
decouper_c2 = ol.dfx_decoupler_combo2
decouper_c2.write(0x0,0)
decouper_c2.write(0x0,1)
ol.pr_download('pr_combo_2','pr_combo_2_combo_score_i4.bit','s_axi_AXILiteS', 'pr_combo_2_combo_score_i4',None)
decouper_c2.write(0x0,0)

decouper_c2 = ol.dfx_decoupler_combo2
decouper_c2.write(0x0,0)
decouper_c2.write(0x0,1)
start_ = time.time()
ol.pr_download('pr_combo_2','pr_combo_2_empty_combo.bit','pr_combo_2_combo_score_i4', 'pr_combo_2_empty_combo',None)
end_ = time.time()
decouper_c2.write(0x0,0)
timecost = end_ - start_
#print('pr_combo_2: cardio_2_empty timecost(ms) = ',timecost*1000)

decouper_c2 = ol.dfx_decoupler_combo2
decouper_c2.write(0x0,0)
decouper_c2.write(0x0,1)
start_ = time.time()
ol.pr_download('pr_combo_2','pr_combo_2_combo_score_i4.bit','pr_combo_2_empty_combo', 'pr_combo_2_combo_score_i4',None)
end_ = time.time()
decouper_c2.write(0x0,0)
timecost = end_ - start_
#print('pr_combo_2: empty_2_cardio timecost(ms) = ',timecost*1000)
###########################################################################################

########################################### PR-combo3 ###########################################
decouper_c3 = ol.dfx_decoupler_combo3
decouper_c3.write(0x0,0)
decouper_c3.write(0x0,1)
ol.pr_download('pr_combo_3','pr_combo_3_combo_score_i4.bit','s_axi_AXILiteS', 'pr_combo_3_combo_score_i4',None)
decouper_c3.write(0x0,0)

decouper_c3 = ol.dfx_decoupler_combo3
decouper_c3.write(0x0,0)
decouper_c3.write(0x0,1)
start_ = time.time()
ol.pr_download('pr_combo_3','pr_combo_3_empty_combo.bit','pr_combo_3_combo_score_i4', 'pr_combo_3_empty_combo',None)
end_ = time.time()
decouper_c3.write(0x0,0)
timecost = end_ - start_
#print('pr_combo_3: cardio_2_empty timecost(ms) = ',timecost*1000)

decouper_c3 = ol.dfx_decoupler_combo3
decouper_c3.write(0x0,0)
decouper_c3.write(0x0,1)
start_ = time.time()
ol.pr_download('pr_combo_3','pr_combo_3_combo_score_i4.bit','pr_combo_3_empty_combo', 'pr_combo_3_combo_score_i4',None)
end_ = time.time()
decouper_c3.write(0x0,0)
timecost = end_ - start_
#print('pr_combo_3: empty_2_cardio timecost(ms) = ',timecost*1000)
###########################################################################################

for i in range(10):
    ########################################### PR1 ###########################################
    decouper_1 = ol.dfx_decoupler_1
    decouper_1.write(0x0,0)
    decouper_1.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr1','pr1_empty_ad.bit','pr1_loda_cardio_c1', 'pr1_empty_ad',None)
    end_ = time.time()
    decouper_1.write(0x0,0)
    timecost = end_ - start_
    #print('pr1: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr1_f2e.append(timecost*1000)

    decouper_1 = ol.dfx_decoupler_1
    decouper_1.write(0x0,0)
    decouper_1.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr1','pr1_loda_cardio_c1.bit','pr1_empty_ad', 'pr1_loda_cardio_c1',None)
    end_ = time.time()
    decouper_1.write(0x0,0)
    timecost = end_ - start_
    #print('pr1: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr1_e2f.append(timecost*1000)
    ###########################################################################################

    ########################################### PR2 ###########################################
    decouper_2 = ol.dfx_decoupler_2
    decouper_2.write(0x0,0)
    decouper_2.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr2','pr2_empty_ad.bit','pr2_loda_cardio_c2', 'pr2_empty_ad',None)
    end_ = time.time()
    decouper_2.write(0x0,0)
    timecost = end_ - start_
    #print('pr2: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr2_f2e.append(timecost*1000)

    decouper_2 = ol.dfx_decoupler_2
    decouper_2.write(0x0,0)
    decouper_2.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr2','pr2_loda_cardio_c2.bit','pr2_empty_ad', 'pr2_loda_cardio_c2',None)
    end_ = time.time()
    decouper_2.write(0x0,0)
    timecost = end_ - start_
    #print('pr2: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr2_e2f.append(timecost*1000)
    ###########################################################################################

    ########################################### PR3###########################################
    decouper_3 = ol.dfx_decoupler_3
    decouper_3.write(0x0,0)
    decouper_3.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr3','pr3_empty_ad.bit','pr3_loda_cardio_c3', 'pr3_empty_ad',None)
    end_ = time.time()
    decouper_3.write(0x0,0)
    timecost = end_ - start_
    #print('pr3: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr3_f2e.append(timecost*1000)

    decouper_3 = ol.dfx_decoupler_3
    decouper_3.write(0x0,0)
    decouper_3.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr3','pr3_loda_cardio_c3.bit','pr3_empty_ad', 'pr3_loda_cardio_c3',None)
    end_ = time.time()
    decouper_3.write(0x0,0)
    timecost = end_ - start_
    #print('pr3: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr3_e2f.append(timecost*1000)
    ###########################################################################################

    ########################################### PR4 ###########################################
    decouper_4 = ol.dfx_decoupler_4
    decouper_4.write(0x0,0)
    decouper_4.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr4','pr4_empty_ad.bit','pr4_loda_cardio_c4', 'pr4_empty_ad',None)
    end_ = time.time()
    decouper_4.write(0x0,0)
    timecost = end_ - start_
    #print('pr4: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr4_f2e.append(timecost*1000)

    decouper_4 = ol.dfx_decoupler_4
    decouper_4.write(0x0,0)
    decouper_4.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr4','pr4_loda_cardio_c4.bit','pr4_empty_ad', 'pr4_loda_cardio_c4',None)
    end_ = time.time()
    decouper_4.write(0x0,0)
    timecost = end_ - start_
    #print('pr4: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr4_e2f.append(timecost*1000)
    ###########################################################################################

    ########################################### PR5 ###########################################
    decouper_5 = ol.dfx_decoupler_5
    decouper_5.write(0x0,0)
    decouper_5.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr5','pr5_empty_ad.bit','pr5_loda_cardio_c5', 'pr5_empty_ad',None)
    end_ = time.time()
    decouper_5.write(0x0,0)
    timecost = end_ - start_
    #print('pr5: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr5_f2e.append(timecost*1000)

    decouper_5 = ol.dfx_decoupler_5
    decouper_5.write(0x0,0)
    decouper_5.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr5','pr5_loda_cardio_c5.bit','pr5_empty_ad', 'pr5_loda_cardio_c5',None)
    end_ = time.time()
    decouper_5.write(0x0,0)
    timecost = end_ - start_
    #print('pr5: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr5_e2f.append(timecost*1000)
    ###########################################################################################

    ########################################### PR6 ###########################################
    decouper_6 = ol.dfx_decoupler_6
    decouper_6.write(0x0,0)
    decouper_6.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr6','pr6_empty_ad.bit','pr6_loda_cardio_c6', 'pr6_empty_ad',None)
    end_ = time.time()
    decouper_6.write(0x0,0)
    timecost = end_ - start_
    #print('pr6: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr6_f2e.append(timecost*1000)

    decouper_6 = ol.dfx_decoupler_6
    decouper_6.write(0x0,0)
    decouper_6.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr6','pr6_loda_cardio_c6.bit','pr6_empty_ad', 'pr6_loda_cardio_c6',None)
    end_ = time.time()
    decouper_6.write(0x0,0)
    timecost = end_ - start_
    #print('pr6: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr6_e2f.append(timecost*1000)
    ###########################################################################################

    ########################################### PR7 ###########################################
    decouper_7 = ol.dfx_decoupler_7
    decouper_7.write(0x0,0)
    decouper_7.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr7','pr7_empty_ad.bit','pr7_loda_cardio_c7', 'pr7_empty_ad',None)
    end_ = time.time()
    decouper_7.write(0x0,0)
    timecost = end_ - start_
    #print('pr7: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr7_f2e.append(timecost*1000)

    decouper_7 = ol.dfx_decoupler_7
    decouper_7.write(0x0,0)
    decouper_7.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr7','pr7_loda_cardio_c7.bit','pr7_empty_ad', 'pr7_loda_cardio_c7',None)
    end_ = time.time()
    decouper_7.write(0x0,0)
    timecost = end_ - start_
    #print('pr7: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_pr7_e2f.append(timecost*1000)
        
    ###########################################################################################

    ########################################### PR-COMBO1 ###########################################
    decouper_c1 = ol.dfx_decoupler_combo1
    decouper_c1.write(0x0,0)
    decouper_c1.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr_combo_1','pr_combo_1_empty_combo.bit','pr_combo_1_combo_score_i4', 'pr_combo_1_empty_combo',None)
    end_ = time.time()
    decouper_c1.write(0x0,0)
    timecost = end_ - start_
    #print('pr_combo_1: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_combo1_f2e.append(timecost*1000)

    decouper_c1 = ol.dfx_decoupler_combo1
    decouper_c1.write(0x0,0)
    decouper_c1.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr_combo_1','pr_combo_1_combo_score_i4.bit','pr_combo_1_empty_combo', 'pr_combo_1_combo_score_i4',None)
    end_ = time.time()
    decouper_c1.write(0x0,0)
    timecost = end_ - start_
    #print('pr_combo_1: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_combo1_e2f.append(timecost*1000)
    ###########################################################################################

    ########################################### PR-COMBO2 ###########################################
    decouper_c2 = ol.dfx_decoupler_combo2
    decouper_c2.write(0x0,0)
    decouper_c2.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr_combo_2','pr_combo_2_empty_combo.bit','pr_combo_2_combo_score_i4', 'pr_combo_2_empty_combo',None)
    end_ = time.time()
    decouper_c2.write(0x0,0)
    timecost = end_ - start_
    #print('pr_combo_2: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_combo2_f2e.append(timecost*1000)

    decouper_c2 = ol.dfx_decoupler_combo2
    decouper_c2.write(0x0,0)
    decouper_c2.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr_combo_2','pr_combo_2_combo_score_i4.bit','pr_combo_2_empty_combo', 'pr_combo_2_combo_score_i4',None)
    end_ = time.time()
    decouper_c2.write(0x0,0)
    timecost = end_ - start_
    #print('pr_combo_2: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_combo2_e2f.append(timecost*1000)
    ###########################################################################################

    ########################################### PR-combo3 ###########################################
    decouper_c3 = ol.dfx_decoupler_combo3
    decouper_c3.write(0x0,0)
    decouper_c3.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr_combo_3','pr_combo_3_empty_combo.bit','pr_combo_3_combo_score_i4', 'pr_combo_3_empty_combo',None)
    end_ = time.time()
    decouper_c3.write(0x0,0)
    timecost = end_ - start_
    #print('pr_combo_3: cardio_2_empty timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_combo3_f2e.append(timecost*1000)

    decouper_c3 = ol.dfx_decoupler_combo3
    decouper_c3.write(0x0,0)
    decouper_c3.write(0x0,1)
    start_ = time.time()
    ol.pr_download('pr_combo_3','pr_combo_3_combo_score_i4.bit','pr_combo_3_empty_combo', 'pr_combo_3_combo_score_i4',None)
    end_ = time.time()
    decouper_c3.write(0x0,0)
    timecost = end_ - start_
    #print('pr_combo_3: empty_2_cardio timecost(ms) = ',timecost*1000)
    if timecost*1000 < 700:
        time_combo3_e2f.append(timecost*1000)
    ###########################################################################################
    print('i = ',i)

print('pr1: cardio_2_empty timecost(ms) = ',np.mean(np.array(time_pr1_f2e)))
print('pr2: cardio_2_empty timecost(ms) = ',np.mean(np.array(time_pr2_f2e)))
print('pr3: cardio_2_empty timecost(ms) = ',np.mean(np.array(time_pr3_f2e)))
print('pr4: cardio_2_empty timecost(ms) = ',np.mean(np.array(time_pr4_f2e)))
print('pr5: cardio_2_empty timecost(ms) = ',np.mean(np.array(time_pr5_f2e)))
print('pr6: cardio_2_empty timecost(ms) = ',np.mean(np.array(time_pr6_f2e)))
print('pr7: cardio_2_empty timecost(ms) = ',np.mean(np.array(time_pr7_f2e)))
print('')
print('pr1: empty_2_cardio timecost(ms) = ',np.mean(np.array(time_pr1_e2f)))
print('pr2: empty_2_cardio timecost(ms) = ',np.mean(np.array(time_pr2_e2f)))
print('pr3: empty_2_cardio timecost(ms) = ',np.mean(np.array(time_pr3_e2f)))
print('pr4: empty_2_cardio timecost(ms) = ',np.mean(np.array(time_pr4_e2f)))
print('pr5: empty_2_cardio timecost(ms) = ',np.mean(np.array(time_pr5_e2f)))
print('pr6: empty_2_cardio timecost(ms) = ',np.mean(np.array(time_pr6_e2f)))
print('pr7: empty_2_cardio timecost(ms) = ',np.mean(np.array(time_pr7_e2f)))
print('')
print('COMBO')
print('combo1: function_2_empty timecost(ms) = ',np.mean(np.array(time_combo1_f2e)))
print('combo2: function_2_empty timecost(ms) = ',np.mean(np.array(time_combo2_f2e)))
print('combo3: function_2_empty timecost(ms) = ',np.mean(np.array(time_combo3_f2e)))
print('')
print('combo1: empty_2_function timecost(ms) = ',np.mean(np.array(time_combo1_e2f)))
print('combo2: empty_2_function timecost(ms) = ',np.mean(np.array(time_combo2_e2f)))
print('combo3: empty_2_function timecost(ms) = ',np.mean(np.array(time_combo3_e2f)))
